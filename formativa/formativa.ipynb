# %%
#importação das bibliotecas
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
#lendo arquivo csv
df = pd.read_csv('dados_produtos.csv', sep=',')

# %%
#vendo informações sobre as colunas do arquivo csv
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_name  100 non-null    object
#  1   rating        100 non-null    float64
#  2   rating_count  100 non-null    int64
#  3   purchased     100 non-null    int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 3.3+ KB

# %%
#mostrando os valores das colunas
df.describe()
# Out:
#              nota  quantdade_notas
# count  100.000000       100.000000
# mean     4.056900      2536.670000
# std      0.588344      1458.312544
# min      3.020000        10.000000
# 25%      3.580000      1433.250000
# 50%      4.105000      2424.000000
# 75%      4.505000      3773.000000
# max      5.000000      4977.000000

# %%
#fazendo boxplot
sns.boxplot(x=df['product_name'], y=df['rating'])
plt.title('produto x nota')
plt.ylabel('nota')
plt.xlabel('produto')
# Out:
# Text(0.5, 0, 'produto')

# %%
#mostrando se em alguma linha tem um valor nulo
df.isnull().sum()
# Out:
# produto            0
# nota               0
# quantdade_notas    0
# comprou            0
# dtype: int64

# %%
#fazendo dicionario para renomear as colunas do arquivo
dic = {'product_name':'produto','rating':'nota','rating_count':'quantdade_notas','purchased':'comprou'}

# %%
#renomeando as colunas do arquivo
df.rename(columns=dic, inplace=True)

# %%
#mostrando as primeiras 10 linhas do arquivo depois de renomear
df.head(10)
# Out:
#      produto  nota  quantdade_notas  comprou
# 0  Televisão  3.04               29        1
# 1    Celular  3.46             3872        0
# 2  Cafeteira  3.25             1187        0
# 3  Televisão  3.77             4097        1
# 4  Videogame  5.00             4738        1
# 5    Celular  3.98             1413        0
# 6       iPod  3.50             1907        0
# 7   Notebook  4.76             3857        0
# 8  Videogame  3.94             2800        1
# 9  Televisão  4.68             2600        0

# %%
#mostrando numero de produtos comprados e não comprados
n_total = df['comprou'].count()
n_compras = df['comprou'].sum()
n_nao_compras = n_total - n_compras
print(f'numero de dados :{n_total}')
print(f'numero de produtos comprados :{n_compras}')
print(f'numero de produtos não comprados :{n_nao_compras}')
# Out:
# numero de dados :100
# numero de produtos comprados :55
# numero de produtos não comprados :45

# %%
#trocando os numeros por palavras
comprou = {0:'não comprou',1:'comprou'}
df = df .replace({'comprou':comprou})
df.head()
# Out:
#      produto  nota  quantdade_notas      comprou
# 0  Televisão  3.04               29      comprou
# 1    Celular  3.46             3872  não comprou
# 2  Cafeteira  3.25             1187  não comprou
# 3  Televisão  3.77             4097      comprou
# 4  Videogame  5.00             4738      comprou

# %%
produtos = df['produto'].unique()
for produto in produtos:
    produto_df = df.loc[df['produto'] == produto]

    x = produto_df.drop(['comprou','produto'],axis=1)
    y = produto_df['comprou']

    x_treino, x_teste, y_treino, y_teste = train_test_split(x,y,test_size=0.2, random_state=42)

    dtc = DecisionTreeClassifier()
    modelo = dtc.fit(x_treino,y_treino)
    y_pred = dtc.predict(x_teste)

    #visualização da arvore
    fig = plt.figure(figsize=(10,8))

    tree.plot_tree(modelo, feature_names=produto_df['nota'].tolist(),class_names=produto_df['comprou'].tolist(),filled=True)
    plt.title(f'arvore decisão - {produto}')

# %%
#transformando variavel para array
nota = df['nota']
compra = df['comprou']
notas = nota.array
compras = compra.array
print(notas)
print(compras)
# Out:
# <PandasArray>
# [3.04, 3.46, 3.25, 3.77,  5.0, 3.98,  3.5, 4.76, 3.94, 4.68, 4.43, 3.14, 4.42,
#  3.14, 3.62,  4.1, 3.93, 4.61, 4.18, 3.11, 4.24, 4.95, 4.49,  3.6, 4.92, 3.12,
#  4.89, 3.76, 3.76, 4.94, 3.02, 4.12, 3.23, 4.45, 4.08,  4.0, 3.31, 3.04,  4.8,
#  4.31, 3.82, 3.45, 3.05, 3.69, 3.45, 4.98, 4.96, 3.75,  5.0, 3.39, 3.33, 4.95,
#   4.8, 4.24, 4.97, 4.23, 4.68, 3.51, 3.16, 4.99, 4.24, 3.49, 4.11, 4.68, 4.39,
#  3.71, 4.55, 3.52, 4.47, 4.23, 4.01, 4.67, 3.79, 3.04, 3.44, 3.78, 3.87, 3.69,
#   4.6, 4.42, 3.38, 4.33, 3.81, 4.36, 4.29, 4.14, 4.12,  3.7, 4.81, 3.84, 3.99,
#  4.64, 4.35, 4.15, 4.78, 4.44, 4.66, 4.33,  3.3, 4.08]
# Length: 100, dtype: float64
# <PandasArray>
# [    'comprou', 'não comprou', 'não comprou',     'comprou',     'comprou',
#  'não comprou', 'não comprou', 'não comprou',     'comprou', 'não comprou',
#  'não comprou',     'comprou',     'comprou', 'não comprou',     'comprou',
#      'comprou',     'comprou',     'comprou',     'comprou', 'não comprou',
#  'não comprou', 'não comprou',     'comprou',     'comprou',     'comprou',
#      'comprou',     'comprou', 'não comprou',     'comprou', 'não comprou',
#      'comprou', 'não comprou',     'comprou',     'comprou', 'não comprou',
#  'não comprou', 'não comprou', 'não comprou',     'comprou',     'comprou',
#      'comprou',     'comprou',     'comprou',     'comprou',     'comprou',
#      'comprou',     'comprou', 'não comprou',     'comprou',     'comprou',
#  'não comprou', 'não comprou',     'comprou', 'não comprou', 'não comprou',
#  'não comprou', 'não comprou', 'não comprou', 'não comprou',     'comprou',
#  'não comprou',     'comprou', 'não comprou', 'não comprou',     'comprou',
#  'não comprou',     'comprou',     'comprou',     'comprou', 'não comprou',
#  'não comprou', 'não comprou',     'comprou', 'não comprou', 'não comprou',
#      'comprou',     'comprou',     'comprou',     'comprou', 'não comprou',
#      'comprou',     'comprou',     'comprou',     'comprou',     'comprou',
#      'comprou', 'não comprou', 'não comprou', 'não comprou', 'não comprou',
#      'comprou',     'comprou', 'não comprou', 'não comprou',     'comprou',
#  'não comprou',     'comprou',     'comprou',     'comprou', 'não comprou']
# Length: 100, dtype: object

# %%
#dividindo em treino e teste
notas_treino, notas_teste, compras_treino, compras_teste = train_test_split(notas.reshape(-1,1),compras.reshape(-1,1),test_size=0.2,random_state=42)

# %%
#criando o modelo
modelo = DecisionTreeClassifier()
modelo.fit(notas_treino,compras_treino)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=modelo.predict(notas_teste)
y_pred
# Out:
# array(['não comprou', 'não comprou', 'não comprou', 'comprou', 'comprou',
#        'comprou', 'comprou', 'comprou', 'não comprou', 'não comprou',
#        'não comprou', 'não comprou', 'não comprou', 'não comprou',
#        'não comprou', 'comprou', 'não comprou', 'comprou', 'não comprou',
#        'não comprou'], dtype=object)

# %%
acuracia = accuracy_score(y_pred, compras_teste)
acuracia
# Out:
# 0.6

# %%
matrix = confusion_matrix(y_pred, compras_teste)
matrix
# Out:
# array([[7, 0],
#        [8, 5]], dtype=int64)

# %%
#mostrando a arvore de decisão
fig = plt.figure(figsize=(50,20))
tree.plot_tree(modelo,feature_names=notas.tolist(), class_names=compras.tolist(), filled=True)
# Out:
# [Text(0.8536585365853658, 0.98, '3.04 <= 4.98\ngini = 0.5\nsamples = 80\nvalue = [40, 40]\nclass = comprou'),
#  Text(0.8211382113821138, 0.94, '3.04 <= 4.93\ngini = 0.5\nsamples = 78\nvalue = [38, 40]\nclass = não comprou'),
#  Text(0.7398373983739838, 0.9, '3.04 <= 4.77\ngini = 0.5\nsamples = 73\nvalue = [37, 36]\nclass = comprou'),
#  Text(0.6747967479674797, 0.86, '3.04 <= 4.665\ngini = 0.499\nsamples = 67\nvalue = [32, 35]\nclass = não comprou'),
#  Text(0.6422764227642277, 0.82, '3.04 <= 4.455\ngini = 0.499\nsamples = 62\nvalue = [32, 30]\nclass = comprou'),
#  Text(0.6097560975609756, 0.78, '3.04 <= 3.96\ngini = 0.497\nsamples = 56\nvalue = [26, 30]\nclass = não comprou'),
#  Text(0.43902439024390244, 0.74, '3.04 <= 3.765\ngini = 0.494\nsamples = 36\nvalue = [20, 16]\nclass = comprou'),
#  Text(0.35772357723577236, 0.7, '3.04 <= 3.695\ngini = 0.497\nsamples = 28\nvalue = [13, 15]\nclass = não comprou'),
#  Text(0.2926829268292683, 0.66, '3.04 <= 3.515\ngini = 0.499\nsamples = 23\nvalue = [12, 11]\nclass = comprou'),
#  Text(0.2601626016260163, 0.62, '3.04 <= 3.495\ngini = 0.488\nsamples = 19\nvalue = [8, 11]\nclass = não comprou'),
#  Text(0.22764227642276422, 0.58, '3.04 <= 3.475\ngini = 0.498\nsamples = 17\nvalue = [8, 9]\nclass = não comprou'),
#  Text(0.1951219512195122, 0.54, '3.04 <= 3.045\ngini = 0.492\nsamples = 16\nvalue = [7, 9]\nclass = não comprou'),
#  Text(0.16260162601626016, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = não comprou'),
#  Text(0.22764227642276422, 0.5, '3.04 <= 3.08\ngini = 0.498\nsamples = 15\nvalue = [7, 8]\nclass = não comprou'),
#  Text(0.1951219512195122, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = comprou'),
#  Text(0.2601626016260163, 0.46, '3.04 <= 3.115\ngini = 0.49\nsamples = 14\nvalue = [6, 8]\nclass = não comprou'),
#  Text(0.22764227642276422, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = não comprou'),
#  Text(0.2926829268292683, 0.42, '3.04 <= 3.13\ngini = 0.497\nsamples = 13\nvalue = [6, 7]\nclass = não comprou'),
#  Text(0.2601626016260163, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = comprou'),
#  Text(0.3252032520325203, 0.38, '3.04 <= 3.455\ngini = 0.486\nsamples = 12\nvalue = [5, 7]\nclass = não comprou'),
#  Text(0.2926829268292683, 0.34, '3.04 <= 3.445\ngini = 0.496\nsamples = 11\nvalue = [5, 6]\nclass = não comprou'),
#  Text(0.2601626016260163, 0.3, '3.04 <= 3.415\ngini = 0.48\nsamples = 10\nvalue = [4, 6]\nclass = não comprou'),
#  Text(0.22764227642276422, 0.26, '3.04 <= 3.36\ngini = 0.494\nsamples = 9\nvalue = [4, 5]\nclass = não comprou'),
#  Text(0.1951219512195122, 0.22, '3.04 <= 3.305\ngini = 0.469\nsamples = 8\nvalue = [3, 5]\nclass = não comprou'),
#  Text(0.16260162601626016, 0.18, '3.04 <= 3.275\ngini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = comprou'),
#  Text(0.13008130081300814, 0.14, '3.04 <= 3.24\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = não comprou'),
#  Text(0.0975609756097561, 0.1, '3.04 <= 3.195\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = comprou'),
#  Text(0.06504065040650407, 0.06, '3.04 <= 3.15\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = não comprou'),
#  Text(0.032520325203252036, 0.02, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = comprou'),
#  Text(0.0975609756097561, 0.02, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = não comprou'),
#  Text(0.13008130081300814, 0.06, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = comprou'),
#  Text(0.16260162601626016, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = não comprou'),
#  Text(0.1951219512195122, 0.14, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = comprou'),
#  Text(0.22764227642276422, 0.18, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = não comprou'),
#  Text(0.2601626016260163, 0.22, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = comprou'),
#  Text(0.2926829268292683, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = não comprou'),
#  Text(0.3252032520325203, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = comprou'),
#  Text(0.35772357723577236, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = não comprou'),
#  Text(0.2601626016260163, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = comprou'),
#  Text(0.2926829268292683, 0.58, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = não comprou'),
#  Text(0.3252032520325203, 0.62, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = comprou'),
#  Text(0.42276422764227645, 0.66, '3.04 <= 3.755\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = não comprou'),
#  Text(0.3902439024390244, 0.62, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = não comprou'),
#  Text(0.45528455284552843, 0.62, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = comprou'),
#  Text(0.5203252032520326, 0.7, '3.04 <= 3.83\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = comprou'),
#  Text(0.4878048780487805, 0.66, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = comprou'),
#  Text(0.5528455284552846, 0.66, '3.04 <= 3.885\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = comprou'),
#  Text(0.5203252032520326, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = não comprou'),
#  Text(0.5853658536585366, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = comprou'),
#  Text(0.7804878048780488, 0.74, '3.04 <= 4.265\ngini = 0.42\nsamples = 20\nvalue = [6, 14]\nclass = não comprou'),
#  Text(0.7154471544715447, 0.7, '3.04 <= 4.145\ngini = 0.26\nsamples = 13\nvalue = [2, 11]\nclass = não comprou'),
#  Text(0.6829268292682927, 0.66, '3.04 <= 4.13\ngini = 0.375\nsamples = 8\nvalue = [2, 6]\nclass = não comprou'),
#  Text(0.6504065040650406, 0.62, '3.04 <= 4.09\ngini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = não comprou'),
#  Text(0.6178861788617886, 0.58, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = não comprou'),
#  Text(0.6829268292682927, 0.58, '3.04 <= 4.105\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = não comprou'),
#  Text(0.6504065040650406, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = comprou'),
#  Text(0.7154471544715447, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = não comprou'),
#  Text(0.7154471544715447, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = comprou'),
#  Text(0.7479674796747967, 0.66, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = não comprou'),
#  Text(0.8455284552845529, 0.7, '3.04 <= 4.34\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = comprou'),
#  Text(0.8130081300813008, 0.66, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = comprou'),
#  Text(0.8780487804878049, 0.66, '3.04 <= 4.405\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = não comprou'),
#  Text(0.8455284552845529, 0.62, '3.04 <= 4.37\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = comprou'),
#  Text(0.8130081300813008, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = não comprou'),
#  Text(0.8780487804878049, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = comprou'),
#  Text(0.9105691056910569, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = não comprou'),
#  Text(0.6747967479674797, 0.78, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = comprou'),
#  Text(0.7073170731707317, 0.82, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = não comprou'),
#  Text(0.8048780487804879, 0.86, '3.04 <= 4.805\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = comprou'),
#  Text(0.7723577235772358, 0.82, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = comprou'),
#  Text(0.8373983739837398, 0.82, '3.04 <= 4.85\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = comprou'),
#  Text(0.8048780487804879, 0.78, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = não comprou'),
#  Text(0.8699186991869918, 0.78, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = comprou'),
#  Text(0.9024390243902439, 0.9, '3.04 <= 4.955\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = não comprou'),
#  Text(0.8699186991869918, 0.86, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = não comprou'),
#  Text(0.9349593495934959, 0.86, '3.04 <= 4.965\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = comprou'),
#  Text(0.9024390243902439, 0.82, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = comprou'),
#  Text(0.967479674796748, 0.82, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = não comprou'),
#  Text(0.8861788617886179, 0.94, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = comprou')]
